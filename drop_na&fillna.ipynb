# %% [markdown]
# # dropna & fillna

# %%
import pandas as pd
var = pd.read_csv("annual.csv")
var
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.dropna()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.dropna(axis=0)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.dropna(how="any")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.dropna(how="all")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.dropna(subset=["Industry_code_NZSIOC"])
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.dropna(inplace=True)

# %%
var.dropna(thresh=1)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.fillna("python")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.fillna({"Industry_aggregation_NZSIOC":"python","Year":2022})
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.fillna(method="ffill")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.fillna(method="bfill", axis=1)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
var.fillna(12,inplace=True)

# %%
var.fillna("python",limit=2)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC
# 0      2021                     Level 1                99999  \
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code
# 0                  All industries  Dollars (millions)           H01  \
# 1                  All industries  Dollars (millions)           H04
# ...
